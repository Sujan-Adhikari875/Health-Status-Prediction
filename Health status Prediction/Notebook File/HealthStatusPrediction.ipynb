# %% [markdown]
# # Import required modules

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Lasso
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, StackingClassifier, VotingClassifier
from sklearn.metrics import accuracy_score,  confusion_matrix, recall_score, precision_score, f1_score
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %% [markdown]
# # Load DataSet

# %%
df = pd.read_csv("novagen_dataset.csv")
df.head()
# Out:
#     Age   BMI  Blood_Pressure  Cholesterol  Glucose_Level  Heart_Rate  \
# 0   2.0  26.0           111.0        198.0           99.0        72.0
# 1   8.0  24.0           121.0        199.0          103.0        75.0
# 2  81.0  27.0           147.0        203.0          100.0        74.0
# 3  25.0  21.0           150.0        199.0          102.0        70.0
# 4  24.0  26.0           146.0        202.0           99.0        76.0
#
#    Sleep_Hours  Exercise_Hours  Water_Intake  Stress_Level  ...  Diet  \
# 0          4.0             1.0           5.0           5.0  ...     1
# 1          2.0             1.0           2.0           9.0  ...     1
# 2         10.0            -0.0           5.0           1.0  ...     2
# 3          7.0             3.0           3.0           3.0  ...     1
# 4         10.0             2.0           5.0           1.0  ...     2
#
#    MentalHealth  PhysicalActivity  MedicalHistory  Allergies  \
# 0             2                 1               0          1
# 1             2                 1               2          2
# 2             0                 0               1          0
# 3             2                 1               2          0
# 4             0                 2               0          2
#
#    Diet_Type__Vegan  Diet_Type__Vegetarian  Blood_Group_AB  Blood_Group_B  \
# 0             False                   True            True          False
# 1             False                  False            True          False
# 2              True                  False           False          False
# 3              True                  False           False           True
# 4             False                   True           False           True
#
#    Blood_Group_O
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 23 columns]

# %% [markdown]
# # OverView of Dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9549 entries, 0 to 9548
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    9549 non-null   float64
#  1   BMI                    9549 non-null   float64
#  2   Blood_Pressure         9549 non-null   float64
#  3   Cholesterol            9549 non-null   float64
#  4   Glucose_Level          9549 non-null   float64
#  5   Heart_Rate             9549 non-null   float64
#  6   Sleep_Hours            9549 non-null   float64
#  7   Exercise_Hours         9549 non-null   float64
#  8   Water_Intake           9549 non-null   float64
#  9   Stress_Level           9549 non-null   float64
#  10  Target                 9549 non-null   int64
#  11  Smoking                9549 non-null   int64
#  12  Alcohol                9549 non-null   int64
#  13  Diet                   9549 non-null   int64
#  14  MentalHealth           9549 non-null   int64
#  15  PhysicalActivity       9549 non-null   int64
#  16  MedicalHistory         9549 non-null   int64
#  17  Allergies              9549 non-null   int64
#  18  Diet_Type__Vegan       9549 non-null   bool
#  19  Diet_Type__Vegetarian  9549 non-null   bool
#  20  Blood_Group_AB         9549 non-null   bool
#  21  Blood_Group_B          9549 non-null   bool
#  22  Blood_Group_O          9549 non-null   bool
# dtypes: bool(5), float64(10), int64(8)
# memory usage: 1.4 MB

# %% [markdown]
# # Checking Missing and Duplicates Values

# %%
df.isnull().sum(), df.duplicated().sum()
# Out:
# (Age                      0
#  BMI                      0
#  Blood_Pressure           0
#  Cholesterol              0
#  Glucose_Level            0
#  Heart_Rate               0
#  Sleep_Hours              0
#  Exercise_Hours           0
#  Water_Intake             0
#  Stress_Level             0
#  Target                   0
#  Smoking                  0
#  Alcohol                  0
#  Diet                     0
#  MentalHealth             0
#  PhysicalActivity         0
#  MedicalHistory           0
#  Allergies                0
#  Diet_Type__Vegan         0
#  Diet_Type__Vegetarian    0
#  Blood_Group_AB           0
#  Blood_Group_B            0
#  Blood_Group_O            0
#  dtype: int64,
#  np.int64(0))

# %%
df.columns
# Out:
# Index(['Age', 'BMI', 'Blood_Pressure', 'Cholesterol', 'Glucose_Level',
#        'Heart_Rate', 'Sleep_Hours', 'Exercise_Hours', 'Water_Intake',
#        'Stress_Level', 'Target', 'Smoking', 'Alcohol', 'Diet', 'MentalHealth',
#        'PhysicalActivity', 'MedicalHistory', 'Allergies', 'Diet_Type__Vegan',
#        'Diet_Type__Vegetarian', 'Blood_Group_AB', 'Blood_Group_B',
#        'Blood_Group_O'],
#       dtype='str')

# %% [markdown]
# # Exploratory Data Analysis

# %%
cols = ['Age','Blood_Pressure', 'Cholesterol', 'Stress_Level', 'Sleep_Hours']

sns.pairplot(
    data=df[cols],
    
)
plt.tight_layout()
plt.show()

# %%
ax = sns.barplot(
    data=df,
    y='MentalHealth',
    x='PhysicalActivity',
    errorbar=('ci', 0)

)
plt.tight_layout()
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.995816'), Text(0, 0, '0.988798'), Text(0, 0, '1.01115')]

# %%
int_df = df.select_dtypes(include="number")
corr_matrix=int_df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Features Selection

# %%
x= df.drop(columns="Target")
y=df["Target"]

# %% [markdown]
# # Train The Model

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# # Data Scaling

# %%
scaler = StandardScaler()
x_train_scaled= scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Logistic Model

# %%
Logistic = LogisticRegression(
    penalty="l2",
    max_iter=1000,
    solver="liblinear"
)
Logistic.fit(x_train_scaled, y_train)
# Out:
# C:\Users\devia\anaconda3\envs\jupyter_env\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# LogisticRegression(max_iter=1000, penalty='l2', solver='liblinear')

# %% [markdown]
# # KNN

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(x_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # svm

# %%
svm = SVC(random_state=42)
svm.fit(x_train_scaled, y_train)
# Out:
# SVC(random_state=42)

# %% [markdown]
# # Decision Tree

# %%
Dt = DecisionTreeClassifier(max_depth=4,
                            random_state=42)
Dt.fit(x_train_scaled, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestClassifier(
    n_estimators=201,
    max_depth=None,
    random_state=42
)
rf.fit(x_train_scaled, y_train)
# Out:
# RandomForestClassifier(n_estimators=201, random_state=42)

# %% [markdown]
# # Stacking Classifier

# %%
meta_model = SVC()
sc = StackingClassifier(
    estimators= [
                ("Knn", knn),
                ("SVM", svm),
                ("DT", Dt),
                ("RandomForest", rf)],
    final_estimator=meta_model,
    cv=5
)
sc.fit(x_train_scaled, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Knn', KNeighborsClassifier()),
#                                ('SVM', SVC(random_state=42)),
#                                ('DT',
#                                 DecisionTreeClassifier(max_depth=4,
#                                                        random_state=42)),
#                                ('RandomForest',
#                                 RandomForestClassifier(n_estimators=201,
#                                                        random_state=42))],
#                    final_estimator=SVC())

# %% [markdown]
# # Voting Classifier

# %%
vc = StackingClassifier(
    estimators= [
                ("Knn", knn),
                ("SVM", svm),
                ("DT", Dt),
                ("RandomForest", rf)],
    cv=5
)
vc.fit(x_train_scaled, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('Knn', KNeighborsClassifier()),
#                                ('SVM', SVC(random_state=42)),
#                                ('DT',
#                                 DecisionTreeClassifier(max_depth=4,
#                                                        random_state=42)),
#                                ('RandomForest',
#                                 RandomForestClassifier(n_estimators=201,
#                                                        random_state=42))])

# %% [markdown]
# # Gradient Boosting

# %%
gd = GradientBoostingClassifier(
    n_estimators = 150,
    learning_rate=0.1, 
    max_depth=3, 
    random_state=42
)
gd.fit(x_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(n_estimators=150, random_state=42)

# %%
models ={ "logistic Regression": Logistic,
           "Knn": knn,
            "SVM": svm,
            "Decision Tree": Dt,
            "RandomForest": rf,
          "Stacking": sc,
          "Voting": vc,
          "Gradient Boosting:": gd
        }

# %% [markdown]
# # Comparision Table

# %%
results = []

for name, model in models.items():
    y_pred = model.predict(x_test_scaled)

    results.append({
        "Model": name,
        
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "F1": f1_score(y_test, y_pred),
        "Confusion Report": confusion_matrix(y_test, y_pred)
    
    })

comparison_df = pd.DataFrame(results).sort_values(
    by="Accuracy",
    ascending=False
)

comparison_df
# Out:
#                  Model  Accuracy  Precision    Recall        F1  \
# 6               Voting  0.948691   0.941639  0.961178  0.951308
# 5             Stacking  0.946946   0.939712  0.959839  0.949669
# 4         RandomForest  0.943455   0.930233  0.963855  0.946746
# 7   Gradient Boosting:  0.933333   0.922777  0.951807  0.937068
# 2                  SVM  0.930192   0.921773  0.946452  0.933950
# 1                  Knn  0.880279   0.887542  0.882195  0.884861
# 3        Decision Tree  0.830716   0.818297  0.868139  0.842481
# 0  logistic Regression  0.812914   0.818061  0.824632  0.821333
#
#              Confusion Report
# 6    [[1282, 89], [58, 1436]]
# 5    [[1279, 92], [60, 1434]]
# 4   [[1263, 108], [54, 1440]]
# 7   [[1252, 119], [72, 1422]]
# 2   [[1251, 120], [80, 1414]]
# 1  [[1204, 167], [176, 1318]]
# 3  [[1083, 288], [197, 1297]]
# 0  [[1097, 274], [262, 1232]]
